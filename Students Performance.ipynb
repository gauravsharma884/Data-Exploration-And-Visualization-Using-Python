# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir("D:\Fore Term 2\DEVP\Projectdatasets_DEVP")

# %%
os.listdir()
# Out:
# ['1-Admission_Predict.csv',
#  '10-melb_data.csv.zip',
#  '11-weatherAUS.csv',
#  '12-country_vaccinations.csv',
#  '13-Fraud Detection.csv',
#  '14 -HRAnalytics.csv',
#  '15-StudentsPerformance.csv',
#  '16- Library_Usage.csv.zip',
#  '17-online_classroom_data.csv',
#  '18-Placement_Data_Full_Class.csv',
#  '19-Cleaned_2018_Flights.zip',
#  '2-Bank-marketing campaign.csv',
#  '20-fifa_data.csv.zip',
#  '3-dropout-ratio-2012-2015.csv',
#  '4-Big mart sales.csv',
#  '5-indian_food.csv',
#  '6-PS4_GamesSales.csv',
#  '7-marketing_data.txt',
#  '8-student-mat.csv',
#  '9-Titanic.csv',
#  'boxplot.png',
#  'dataset_description.docx',
#  'gender.png',
#  'reading_boxplot.png',
#  'score.png',
#  'writing_boxplot.png']

# %%
data=pd.read_csv("15-StudentsPerformance.csv")

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#Identifying Data Types of the Columns

data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data.shape
# Out:
# (1000, 8)

# %%
# Changing race/ethnicity to race

data = data.rename(columns= {"race/ethnicity":"race"})

# %%
# Graphical Representation of number of females and male students
sns.countplot(x='gender', data=data)
plt.savefig('gender.png')

# %%
data.head()
# Out:
#    gender     race parental level of education         lunch  \
# 0  female  group B           bachelor's degree      standard
# 1  female  group C                some college      standard
# 2  female  group B             master's degree      standard
# 3    male  group A          associate's degree  free/reduced
# 4    male  group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.countplot(x='race', data=data)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
sns.countplot(x='lunch', data=data)
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
data.isnull().sum()
# Out:
# gender                         0
# race                           0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
plt.savefig('gender.png')

# %%
data['math score'].value_counts()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: math score, Length: 81, dtype: int64

# %%
#math score
sns.boxplot(x='gender', y='math score', data=data)
plt.savefig('boxplot.png')

# %%
p = sns.countplot(x="math score", data = data, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# Lets suppose the pass marks for Maths exam is 35 to further explore the data

# %%
passmark = 35

# %% [markdown]
# How many students pass in exam ?

# %%
data['Math_PassStatus'] = np.where(data['math score']< passmark , 'F','P')
data.Math_PassStatus.value_counts()
# Out:
# P    978
# F     22
# Name: Math_PassStatus, dtype: int64

# %%
p= sns.countplot(x='parental level of education', data= data, hue='Math_PassStatus' , palette= 'bright')
_= plt.setp(p.get_xticklabels(), rotation= 90)

# %% [markdown]
# Exploring Reading Score

# %%
data['reading score'].value_counts()
# Out:
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: reading score, Length: 72, dtype: int64

# %%
#reading score
sns.boxplot(x='gender', y='reading score', data=data)
plt.savefig('reading_boxplot.png')

# %%
sns.countplot(x= 'reading score', data=data, palette= 'muted')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# How many Students passed in Reading ?

# %%
data['Reading_PassStatus'] = np.where(data['reading score']<passmark, 'F', 'P')
data.Reading_PassStatus.value_counts()
# Out:
# P    985
# F     15
# Name: Reading_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = data, hue='Reading_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# Exploring Writing Score

# %%
data['writing score'].value_counts()
# Out:
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 28     1
# 35     1
# 19     1
# 22     1
# 23     1
# Name: writing score, Length: 77, dtype: int64

# %%
#writing score
sns.boxplot(x='gender', y='writing score', data=data)
plt.savefig('writing_boxplot.png')

# %%
p = sns.countplot(x="writing score", data = data, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
data['writing score'].value_counts(normalize=True)
data['writing score'].value_counts(dropna=False).plot.bar(figsize= (18,10),color='Blue')
plt.title("Comparison of writing scores")
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %% [markdown]
# How Many Students passed in writing

# %%
data['Writing_PassStatus'] = np.where(data['writing score']<passmark, 'F', 'P')
data.Writing_PassStatus.value_counts()
# Out:
# P    983
# F     17
# Name: Writing_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = data, hue='Writing_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
male=data.where(data.gender=="male")
male=male.dropna()

# %%
male
# Out:
#     gender     race parental level of education         lunch  \
# 3     male  group A          associate's degree  free/reduced
# 4     male  group C                some college      standard
# 7     male  group B                some college  free/reduced
# 8     male  group D                 high school  free/reduced
# 10    male  group C          associate's degree      standard
# ..     ...      ...                         ...           ...
# 985   male  group A                 high school      standard
# 987   male  group E            some high school      standard
# 990   male  group E                 high school  free/reduced
# 994   male  group A                 high school      standard
# 996   male  group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# 7                      none        40.0           43.0           39.0
# 8                 completed        64.0           64.0           67.0
# 10                     none        58.0           54.0           52.0
# ..                      ...         ...            ...            ...
# 985                    none        57.0           51.0           54.0
# 987               completed        81.0           75.0           76.0
# 990               completed        86.0           81.0           75.0
# 994                    none        63.0           63.0           62.0
# 996                    none        62.0           55.0           55.0
#
#     Math_PassStatus Reading_PassStatus Writing_PassStatus
# 3                 P                  P                  P
# 4                 P                  P                  P
# 7                 P                  P                  P
# 8                 P                  P                  P
# 10                P                  P                  P
# ..              ...                ...                ...
# 985               P                  P                  P
# 987               P                  P                  P
# 990               P                  P                  P
# 994               P                  P                  P
# 996               P                  P                  P
#
# [482 rows x 11 columns]

# %%
male=male.dropna()

# %%
male
# Out:
#     gender     race parental level of education         lunch  \
# 3     male  group A          associate's degree  free/reduced
# 4     male  group C                some college      standard
# 7     male  group B                some college  free/reduced
# 8     male  group D                 high school  free/reduced
# 10    male  group C          associate's degree      standard
# ..     ...      ...                         ...           ...
# 985   male  group A                 high school      standard
# 987   male  group E            some high school      standard
# 990   male  group E                 high school  free/reduced
# 994   male  group A                 high school      standard
# 996   male  group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none        47.0           57.0           44.0
# 4                      none        76.0           78.0           75.0
# 7                      none        40.0           43.0           39.0
# 8                 completed        64.0           64.0           67.0
# 10                     none        58.0           54.0           52.0
# ..                      ...         ...            ...            ...
# 985                    none        57.0           51.0           54.0
# 987               completed        81.0           75.0           76.0
# 990               completed        86.0           81.0           75.0
# 994                    none        63.0           63.0           62.0
# 996                    none        62.0           55.0           55.0
#
#     Math_PassStatus Reading_PassStatus Writing_PassStatus
# 3                 P                  P                  P
# 4                 P                  P                  P
# 7                 P                  P                  P
# 8                 P                  P                  P
# 10                P                  P                  P
# ..              ...                ...                ...
# 985               P                  P                  P
# 987               P                  P                  P
# 990               P                  P                  P
# 994               P                  P                  P
# 996               P                  P                  P
#
# [482 rows x 11 columns]

# %%
female=data.where(data.gender=="female")
female=female.dropna()

# %%
female
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 5    female  group B          associate's degree      standard
# 6    female  group B                some college      standard
# ..      ...      ...                         ...           ...
# 993  female  group D           bachelor's degree  free/reduced
# 995  female  group E             master's degree      standard
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 5                      none        71.0           83.0           78.0
# 6                 completed        88.0           95.0           92.0
# ..                      ...         ...            ...            ...
# 993                    none        62.0           72.0           74.0
# 995               completed        88.0           99.0           95.0
# 997               completed        59.0           71.0           65.0
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0
#
#     Math_PassStatus Reading_PassStatus Writing_PassStatus
# 0                 P                  P                  P
# 1                 P                  P                  P
# 2                 P                  P                  P
# 5                 P                  P                  P
# 6                 P                  P                  P
# ..              ...                ...                ...
# 993               P                  P                  P
# 995               P                  P                  P
# 997               P                  P                  P
# 998               P                  P                  P
# 999               P                  P                  P
#
# [518 rows x 11 columns]

# %%
data[['math score', 'writing score', 'reading score']].hist(figsize=(10, 4))
plt.savefig('score.png')

# %%
plt.savefig('score.png')

# %%
male['math score'].describe()
# Out:
# count    482.000000
# mean      68.728216
# std       14.356277
# min       27.000000
# 25%       59.000000
# 50%       69.000000
# 75%       79.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
male['reading score'].describe()
# Out:
# count    482.000000
# mean      65.473029
# std       13.931832
# min       23.000000
# 25%       56.000000
# 50%       66.000000
# 75%       75.000000
# max      100.000000
# Name: reading score, dtype: float64

# %%
male['writing score'].describe()
# Out:
# count    482.000000
# mean      63.311203
# std       14.113832
# min       15.000000
# 25%       53.000000
# 50%       64.000000
# 75%       73.750000
# max      100.000000
# Name: writing score, dtype: float64

# %%
female['math score'].describe()
# Out:
# count    518.000000
# mean      63.633205
# std       15.491453
# min        0.000000
# 25%       54.000000
# 50%       65.000000
# 75%       74.000000
# max      100.000000
# Name: math score, dtype: float64

# %%
female['reading score'].describe()
# Out:
# count    518.000000
# mean      72.608108
# std       14.378245
# min       17.000000
# 25%       63.250000
# 50%       73.000000
# 75%       83.000000
# max      100.000000
# Name: reading score, dtype: float64

# %%
female['writing score'].describe()
# Out:
# count    518.000000
# mean      72.467181
# std       14.844842
# min       10.000000
# 25%       64.000000
# 50%       74.000000
# 75%       82.000000
# max      100.000000
# Name: writing score, dtype: float64

# %%
data['OverAll_PassStatus'] = data.apply(lambda x : 'F' if x['Math_PassStatus'] == 'F' or 
                                    x['Reading_PassStatus'] == 'F' or x['Writing_PassStatus'] == 'F' else 'P', axis =1)

data.OverAll_PassStatus.value_counts()
# Out:
# P    971
# F     29
# Name: OverAll_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = data, hue='OverAll_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
data['Total_Marks'] = data['math score']+data['reading score']+data['writing score']
data['Percentage'] = data['Total_Marks']/3

# %%
p = sns.countplot(x="Percentage", data = data, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=0)

# %% [markdown]
# #let us assign the grades to further analyse the data
# Grading
# above 80 = A Grade
# 70 to 80 = B Grade
# 60 to 70 = C Grade
# 50 to 60 = D Grade
# 35 to 50 = E Grade
# below 35 = F Grade ( means Fail )

# %%
def GetGrade(Percentage, OverAll_PassStatus):
    if ( OverAll_PassStatus == 'F'):
        return 'F'    
    if ( Percentage >= 80 ):
        return 'A'
    if ( Percentage >= 70):
        return 'B'
    if ( Percentage >= 60):
        return 'C'
    if ( Percentage >= 50):
        return 'D'
    if ( Percentage >= 35):
        return 'E'
    else: 
        return 'F'

data['Grade'] = data.apply(lambda x : GetGrade(x['Percentage'], x['OverAll_PassStatus']), axis=1)

data.Grade.value_counts()
# Out:
# B    261
# C    256
# A    198
# D    182
# E     74
# F     29
# Name: Grade, dtype: int64

# %%
sns.countplot(x="Grade", data = data, order=['A','B','C','D','E','F'],  palette="muted")
plt.show()

# %%
p = sns.countplot(x='parental level of education', data = data, hue='Grade', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# Now let's check wether the marks of students changes according to the type of lunch.

# %%
marks_according_lunch = data[['math score','reading score','writing score']].groupby(data['lunch']).sum()

marks_according_lunch
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced       20917          22952          22373
# standard           45172          46217          45681

# %%
data.lunch.value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data.columns
# Out:
# Index(['gender', 'race', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Math_PassStatus', 'Reading_PassStatus',
#        'Writing_PassStatus', 'OverAll_PassStatus', 'Total_Marks', 'Percentage',
#        'Grade'],
#       dtype='object')

# %%
data = data.rename(columns= {"test preparation course": "course"})

# %% [markdown]
# Result on basis of Test Preparation Course

# %%
marks_test_pre = data[['math score','reading score','writing score']].groupby(data['course']).sum()

marks_test_pre
# Out:
#            math score  reading score  writing score
# course
# completed       24951          26454          26642
# none            41138          42715          41412

# %%
data.head()
# Out:
#    gender     race parental level of education         lunch     course  \
# 0  female  group B           bachelor's degree      standard       none
# 1  female  group C                some college      standard  completed
# 2  female  group B             master's degree      standard       none
# 3    male  group A          associate's degree  free/reduced       none
# 4    male  group C                some college      standard       none
#
#    math score  reading score  writing score Math_PassStatus  \
# 0          72             72             74               P
# 1          69             90             88               P
# 2          90             95             93               P
# 3          47             57             44               P
# 4          76             78             75               P
#
#   Reading_PassStatus Writing_PassStatus OverAll_PassStatus  Total_Marks  \
# 0                  P                  P                  P          218
# 1                  P                  P                  P          247
# 2                  P                  P                  P          278
# 3                  P                  P                  P          148
# 4                  P                  P                  P          229
#
#    Percentage Grade
# 0   72.666667     B
# 1   82.333333     A
# 2   92.666667     A
# 3   49.333333     E
# 4   76.333333     B

# %%
data.course.value_counts()
# Out:
# none         642
# completed    358
# Name: course, dtype: int64

# %%
sns.countplot(x="course", data = data,   palette="muted")
plt.show()

# %%
_= sns.pairplot(data, hue='gender')

# %%
#  comparison between gender and race

x=pd.crosstab(data['gender'], data['race'])
x.div(x.sum(1).astype(float), axis=0).plot(kind='bar', stacked= True, figsize=(4,4))
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue ='course')

# %%
#Calculate Total score as a new column
data['Total_Marks'] = data['math score'] + data['reading score'] + data['writing score']

# %%
#Calculate Percentage as a new column

data['percentage'] = (data['Total_Marks']/300)*100

# %%
#Analyzing the relation between course and total Score

plt.figure(figsize=(5,5))
sns.barplot(x='gender', y='percentage',data=data, hue='course')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='percentage'>

# %% [markdown]
# Students who completed the test preparation course had performed slightly better than others

# %%
data1= data.groupby('gender')['math score'].mean()
data1
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
data1= data.groupby('gender')['reading score'].mean()
data1
# Out:
# gender
# female    72.608108
# male      65.473029
# Name: reading score, dtype: float64

# %%
data1= data.groupby('gender')['writing score'].mean()
data1
# Out:
# gender
# female    72.467181
# male      63.311203
# Name: writing score, dtype: float64

# %%
data1= data.groupby('parental level of education')['math score'].mean()
data1
# Out:
# parental level of education
# associate's degree    67.882883
# bachelor's degree     69.389831
# high school           62.137755
# master's degree       69.745763
# some college          67.128319
# some high school      63.497207
# Name: math score, dtype: float64

# %%
data1= data.groupby('parental level of education')['Total_Marks'].mean()
data1
# Out:
# parental level of education
# associate's degree    208.707207
# bachelor's degree     215.771186
# high school           189.290816
# master's degree       220.796610
# some college          205.429204
# some high school      195.324022
# Name: Total_Marks, dtype: float64

# %%
# As numeric values were not much we were not able to ceate barplot

# %%
sns.stripplot(x = 'Total_Marks', y = 'parental level of education', data = data)
# Out:
# <AxesSubplot:xlabel='Total_Marks', ylabel='parental level of education'>

# %%
plt.scatter(data['Total_Marks'], data['parental level of education'])

# %%
sns.stripplot(x = 'Total_Marks', y = 'course', data = data)
# Out:
# <AxesSubplot:xlabel='Total_Marks', ylabel='course'>

# %%
sns.stripplot(x = 'Total_Marks', y = 'race', data = data)
# Out:
# <AxesSubplot:xlabel='Total_Marks', ylabel='race'>

# %% [markdown]
# Interpretation
#
# 1) As seen above, there are no missing ( null ) values in this dataframe but in real scenarios we need work on dataset with a lot of missing value 2) 978 students passed in Maths exam when minimum passing marks is 35 3) 985 students passed in reading exam when minimum passing marks is 35. 4) 983 students passed in writing exam when minimum passing marks is 35. 5) No students has failed whose parents have Master Degree and highest number of students passing exam have parents with associate degree 6) Students scoring between 60-80 have highest frequency
